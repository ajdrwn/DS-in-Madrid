# %% [markdown]
# ### 🔧 **Setup**

# %%
# Install required libraries
# !pip install pandas numpy
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
# Import libraries
import pandas as pd
import numpy as np

# %% [markdown]
# ## 📍 **Section 1: Series - One-Dimensional Data**

# %%
# Creating a Series
x = 20
print(type(x))
d = pd.array
s = pd.Series([1, 3, 5, np.nan, 6, 8])
print(s)
# Out:
# <class 'int'>
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %% [markdown]
# ### 📘 What this does:
# * `pd.Series(...)` creates a one-dimensional array-like object.
# * `np.nan` stands for "Not a Number", a missing value.

# %% [markdown]
# ### ✏️ Exercise 1:
# * Create your own Series with names of fruits.
# * Include a missing value using `np.nan`.

# %%
# Your code here:
my_series = pd.Series([ "apple", "orange", np.nan, "banana", "peach", "avocado" ])
print(my_series)
# Out:
# 0      apple
# 1     orange
# 2        NaN
# 3     banana
# 4      peach
# 5    avocado
# dtype: object

# %% [markdown]
# ## 📍 **Section 2: DataFrame - Two-Dimensional Data**
#
# ✅ 1. Tabular Data Representation
# Mimics a spreadsheet or SQL table: rows + labeled columns.
#
# Makes data easy to read, access, and interpret.
#
# ✅ 2. Labeled Indexing
# You can access data using row/column labels, not just numbers.
#
# This improves clarity and reduces errors in complex analyses.

# %%
# Create a datetime index
dates = pd.date_range("20220101", periods=6)
# Create a DataFrame with random numbers
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2022-01-01 -0.595017  0.292332 -0.118636 -1.199000
# 2022-01-02 -0.406586 -0.553356  0.427823  0.251493
# 2022-01-03  0.008105 -1.315249 -0.168124 -0.766516
# 2022-01-04 -1.121042 -0.023094  1.193678 -1.809409
# 2022-01-05  1.492300 -0.417432  0.588607 -1.148212
# 2022-01-06  0.350235 -0.569575 -0.450493  0.663696

# %% [markdown]
# ### 📘 Explanation:
# * `date_range()` creates dates.
# * `np.random.randn()` creates random data.
# * `DataFrame(...)` builds a table from the array.

# %% [markdown]
# ### ✏️ Exercise 2:
# * Create a DataFrame with 5 rows, 3 columns (`X`, `Y`, `Z`), and use your own numbers.

# %%
# Your code here


index = pd.date_range( "20250624", periods = 5 )
my_df = pd.DataFrame(np.random.randn(5, 3), index = index, columns = list("XYZ"))


print(my_df)
# Out:
#                    X         Y         Z
# 2025-06-24 -0.445766 -1.851309  1.141161
# 2025-06-25 -0.038791 -0.222933  0.567905
# 2025-06-26 -1.657857 -0.832642  0.634814
# 2025-06-27  0.475843 -0.693711  0.532537
# 2025-06-28  0.343157  0.154349  0.022343

# %% [markdown]
# ## 📍 **Section 3: DataFrame from a Dictionary**

# %%
df2 = pd.DataFrame({
    "A": 1.0,
    "B": pd.Timestamp("20220101"),
    "C": pd.Series([1, 2, 3, 4], dtype="float32"),
    "D": np.array([3] * 4, dtype="int32"),
    "E": pd.Categorical(["test", "train", "test", "train"]),
    "F": "foo",
})
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2022-01-01  1.0  3   test  foo
# 1  1.0 2022-01-01  2.0  3  train  foo
# 2  1.0 2022-01-01  3.0  3   test  foo
# 3  1.0 2022-01-01  4.0  3  train  foo

# %% [markdown]
# ### 📘 Explanation:
# You can pass a Python dictionary to create a more structured and labeled dataset.

# %% [markdown]
# ### ✏️ Exercise 3:
# * Create a DataFrame with columns for your `name`, `age`, and `student status (True/False)`.

# %%
# Your code here

my_df2 = pd.DataFrame({
    "name": ["Andrew", "Tony", "JT", "Ethan" ],
    "age": [ 21, 19, 19, 18 ],
    "student status": True,

})

print(my_df2)
# Out:
#      name  age  student status
# 0  Andrew   21            True
# 1    Tony   19            True
# 2      JT   19            True
# 3   Ethan   18            True

# %% [markdown]
# ## 📍 **Section 4: Inspecting Data**

# %%
# View top and bottom rows
print(df.head())
print(df.tail())
# Out:
#                    A         B         C         D
# 2022-01-01 -0.595017  0.292332 -0.118636 -1.199000
# 2022-01-02 -0.406586 -0.553356  0.427823  0.251493
# 2022-01-03  0.008105 -1.315249 -0.168124 -0.766516
# 2022-01-04 -1.121042 -0.023094  1.193678 -1.809409
# 2022-01-05  1.492300 -0.417432  0.588607 -1.148212
#                    A         B         C         D
# 2022-01-02 -0.406586 -0.553356  0.427823  0.251493
# 2022-01-03  0.008105 -1.315249 -0.168124 -0.766516
# 2022-01-04 -1.121042 -0.023094  1.193678 -1.809409
# 2022-01-05  1.492300 -0.417432  0.588607 -1.148212
# 2022-01-06  0.350235 -0.569575 -0.450493  0.663696

# %%
# Show index and column names
print(df.index)
print(df.columns)
# Out:
# DatetimeIndex(['2022-01-01', '2022-01-02', '2022-01-03', '2022-01-04',
#                '2022-01-05', '2022-01-06'],
#               dtype='datetime64[ns]', freq='D')
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
# Convert to NumPy array (for computation)
df.to_numpy()
# Out:
# array([[-0.59501688,  0.29233171, -0.11863637, -1.19900006],
#        [-0.40658557, -0.55335611,  0.42782321,  0.25149318],
#        [ 0.00810481, -1.3152486 , -0.16812445, -0.76651562],
#        [-1.1210419 , -0.02309385,  1.19367767, -1.80940943],
#        [ 1.49230041, -0.4174316 ,  0.58860693, -1.14821191],
#        [ 0.35023461, -0.56957465, -0.45049289,  0.66369619]])

# %%
# Check column data types
df2.dtypes
# Out:
# A          float64
# B    datetime64[s]
# C          float32
# D            int32
# E         category
# F           object
# dtype: object

# %% [markdown]
# ### ✏️ Exercise 4:
# * Use `.head()` and `.tail()` to inspect your own DataFrame from Exercise 3.

# %%
my_df2.head()
my_df2.tail()
# Out:
#      name  age  student status
# 0  Andrew   21            True
# 1    Tony   19            True
# 2      JT   19            True
# 3   Ethan   18            True

# %% [markdown]
# ## 📍 **Section 5: Summary Statistics**

# %%
# Summary of statistics
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean  -0.045334 -0.431062  0.245476 -0.667991
# std    0.907023  0.548790  0.606315  0.942758
# min   -1.121042 -1.315249 -0.450493 -1.809409
# 25%   -0.547909 -0.565520 -0.155752 -1.186303
# 50%   -0.199240 -0.485394  0.154593 -0.957364
# 75%    0.264702 -0.121678  0.548411 -0.003009
# max    1.492300  0.292332  1.193678  0.663696

# %%
# Transpose rows and columns
df.T
# Out:
#    2022-01-01  2022-01-02  2022-01-03  2022-01-04  2022-01-05  2022-01-06
# A   -0.595017   -0.406586    0.008105   -1.121042    1.492300    0.350235
# B    0.292332   -0.553356   -1.315249   -0.023094   -0.417432   -0.569575
# C   -0.118636    0.427823   -0.168124    1.193678    0.588607   -0.450493
# D   -1.199000    0.251493   -0.766516   -1.809409   -1.148212    0.663696

# %%
# Sort by column names
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2022-01-01 -1.199000 -0.118636  0.292332 -0.595017
# 2022-01-02  0.251493  0.427823 -0.553356 -0.406586
# 2022-01-03 -0.766516 -0.168124 -1.315249  0.008105
# 2022-01-04 -1.809409  1.193678 -0.023094 -1.121042
# 2022-01-05 -1.148212  0.588607 -0.417432  1.492300
# 2022-01-06  0.663696 -0.450493 -0.569575  0.350235

# %%
# Sort by values in a specific column
df.sort_values(by="C")
# Out:
#                    A         B         C         D
# 2022-01-06  0.350235 -0.569575 -0.450493  0.663696
# 2022-01-03  0.008105 -1.315249 -0.168124 -0.766516
# 2022-01-01 -0.595017  0.292332 -0.118636 -1.199000
# 2022-01-02 -0.406586 -0.553356  0.427823  0.251493
# 2022-01-05  1.492300 -0.417432  0.588607 -1.148212
# 2022-01-04 -1.121042 -0.023094  1.193678 -1.809409

# %% [markdown]
# ### ✏️ Exercise 5:
# * Add a new column `Score` to your DataFrame and sort it.

# %%
df2['Score'] = [99, 65, 75, 84]
df2.sort_values(by = 'Score')
# Out:
#      A          B    C  D      E    F  Score
# 1  1.0 2022-01-01  2.0  3  train  foo     65
# 2  1.0 2022-01-01  3.0  3   test  foo     75
# 3  1.0 2022-01-01  4.0  3  train  foo     84
# 0  1.0 2022-01-01  1.0  3   test  foo     99

# %% [markdown]
# ## 📍 **Section 6: Selecting Columns**

# %%
# Select a column using bracket notation
df["A"]
# Out:
# 2022-01-01   -0.595017
# 2022-01-02   -0.406586
# 2022-01-03    0.008105
# 2022-01-04   -1.121042
# 2022-01-05    1.492300
# 2022-01-06    0.350235
# Freq: D, Name: A, dtype: float64

# %% [markdown]
# ### ✏️ Exercise 6:
# * Print the column `A` and plot it using `.plot()` (Optional: if you're in Colab or Jupyter)

# %%
print(df["A"])
df["A"].plot()
# Out:
# 2022-01-01   -0.595017
# 2022-01-02   -0.406586
# 2022-01-03    0.008105
# 2022-01-04   -1.121042
# 2022-01-05    1.492300
# 2022-01-06    0.350235
# Freq: D, Name: A, dtype: float64
# <Axes: >

# %% [markdown]
# ## ✅ **Final Task (Mini Project)**:
# Use what you've learned to:
# * Create a DataFrame with 5 students and their grades in Math, Science, and English.
# * Calculate the average for each student.
# * Sort the DataFrame by average grade.
# * Display summary statistics.

# %%
exercise6 = pd.DataFrame({
    "Name": [ "Andrew", "Bilbo", "Ethan", "Daniel", "Carson" ] ,
    "Math": [ 87, 65, 82, 96, 87] ,
    "Science": [ 90, 86, 75, 89, 64 ] ,
    "English": [ 83, 96, 87, 88, 79 ] ,
})


exercise6['Averages'] = exercise6[['Math', 'Science', 'English']].mean(axis = 1)

print(exercise6.sort_values(by = 'Averages'))

exercise6.describe()
# Out:
#      Name  Math  Science  English   Averages
# 4  Carson    87       64       79  76.666667
# 2   Ethan    82       75       87  81.333333
# 1   Bilbo    65       86       96  82.333333
# 0  Andrew    87       90       83  86.666667
# 3  Daniel    96       89       88  91.000000
#             Math   Science    English   Averages
# count   5.000000   5.00000   5.000000   5.000000
# mean   83.400000  80.80000  86.600000  83.600000
# std    11.458621  11.12205   6.348228   5.453847
# min    65.000000  64.00000  79.000000  76.666667
# 25%    82.000000  75.00000  83.000000  81.333333
# 50%    87.000000  86.00000  87.000000  82.333333
# 75%    87.000000  89.00000  88.000000  86.666667
# max    96.000000  90.00000  96.000000  91.000000
